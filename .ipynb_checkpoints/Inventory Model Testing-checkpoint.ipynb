# %%
import gym
import numpy as np
import inventory_model
from evaluate import *
from ppo_evaluate import ppo_evaluate

from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

# %%
# CONFIG = {'h': 1, 'p': 1, 'L': 10, 'max_demand': 6, 'max_inventory': 100}
# ContCONFIG = {'h': 1, 'p': 0.25, 'L': 100, 'lambda': 1}

# %%
# env = gym.make('inventory_model-v0', config=CONFIG)
# cont_env = gym.make('inventory_cont_config_validation_model-v0', 
#                     config=ContCONFIG)

# %%
# print(env.state)
# print(env.action_space)
# print(env.observation_space) # openAI calles states observations :/

# print(cont_env.state)
# print(cont_env.action_space)
# print(cont_env.observation_space)

# %%
# print(cont_env.action_space.sample())
# print(env.action_space.sample())
# print('***')

# env.state = np.array([0]*(CONFIG['L']+1))
# print(env.step(1))
# print('***')

# cont_env.state = np.array([0]*(CONFIG['L']+1))
# print(cont_env.step(np.array([[1.0]])))
# print('***')

# %% [markdown]
# The following cell defines the random policy model and the constant policy model, and then calls the evaluate function. When ordering constant 1 or 2, the policy is stable.

# %%
# def random_model(env):
#     def policy(state):
#         return env.action_space.sample()
#     return policy

# %%
#compare optimal constant order

numiter = 5000
# print ('discrete state space with Bernoulli demand under random policy:')
# evaluate(random_model, env, numiter)
# print()
# print ('continuous state space with Exp(1) demand under random policy:')
# evaluate(random_model, cont_env, numiter)
# print()

# for i in range(1,6):
#     def constant_model(env):
#         def policy(state):
#             return i
#         return policy
#     print ('discrete state space under constant %s order policy:' %i)
#     evaluate(constant_model, env, numiter)
#     print()

L = 100
res_arr = []
res_std_arr = []

for p in [0.25,1,4,9,39,99]:
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1}
    cont_env = gym.make('inventory_cont_config_validation_model-v0', 
                    config=ContCONFIG)
    sub_res = []
    sub_res_std = []
    for i in range(0,22):
        def constant_model(env):
            def policy(state):
                return np.array([i/20])
#                 return np.array([0])
    #             return i/100
            return policy
        print ('continuous state space under constant %s order policy:' %(i/20))
        avg, std = evaluate(constant_model, cont_env, numiter)
        sub_res.append(avg)
        sub_res_std.append(std)
        print()
    res_arr.append(-max(sub_res))
    res_std_arr.append(sub_res_std[np.argmax(sub_res)])
# Out:
# continuous state space under constant 0.0 order policy:
# mean:  -0.2500356502357311
# standard deviation: 0.0020962661399634586
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.23080713937436928
# standard deviation: 0.0016523026008005428
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22511411884146576
# standard deviation: 0.0014858901420522607
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.23978865921255524
# standard deviation: 0.0011405833661898687
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.2828744526394216
# standard deviation: 0.0012471876000959854
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.37802472725715297
# standard deviation: 0.005473491257340607
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5545765891977759
# standard deviation: 0.009952926371503076
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.8975948182997726
# standard deviation: 0.03514870912776061
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.616879164030313
# standard deviation: 0.11824857679109839
#
# continuous state space under constant 0.9 order policy:
# mean:  -4.068897480931331
# standard deviation: 0.5875147963361602
#
# continuous state space under constant 1.0 order policy:
# mean:  -75.78163445154618
# standard deviation: 40.862574558862
#
# continuous state space under constant 1.1 order policy:
# mean:  -1000.4307243479359
# standard deviation: 54.92628377883046
#
# continuous state space under constant 1.2 order policy:
# mean:  -2023.42811203735
# standard deviation: 64.3646839984407
#
# continuous state space under constant 1.3 order policy:
# mean:  -3033.0634632976626
# standard deviation: 35.09385922580148
#
# continuous state space under constant 1.4 order policy:
# mean:  -4029.722351935858
# standard deviation: 77.94911962109808
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.25024102285774036
# standard deviation: 0.001671892757788306
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.2307016088100206
# standard deviation: 0.002203128009108226
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22508371533693178
# standard deviation: 0.0017690735956858868
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.2394646163684852
# standard deviation: 0.0014888430119719609
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.2836435357303756
# standard deviation: 0.002142720780566196
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.37529270343829524
# standard deviation: 0.0061437173429380095
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5490489789988311
# standard deviation: 0.009592309170633561
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.8921077348685191
# standard deviation: 0.03571540107395545
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.6212325280281672
# standard deviation: 0.08165891727218481
#
# continuous state space under constant 0.9 order policy:
# mean:  -4.019632947518406
# standard deviation: 0.3477785824254407
#
# continuous state space under constant 1.0 order policy:
# mean:  -88.06291706182493
# standard deviation: 39.997818114933736
#
# continuous state space under constant 1.1 order policy:
# mean:  -1035.123727734371
# standard deviation: 81.218334799883
#
# continuous state space under constant 1.2 order policy:
# mean:  -2057.9545402923673
# standard deviation: 77.69204719772578
#
# continuous state space under constant 1.3 order policy:
# mean:  -2989.732710385044
# standard deviation: 85.86230990930888
#
# continuous state space under constant 1.4 order policy:
# mean:  -3975.319817141562
# standard deviation: 93.57909948484526
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.2502425519601331
# standard deviation: 0.0020493605559969885
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.230545615006213
# standard deviation: 0.0009489973473319905
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22474387345237154
# standard deviation: 0.001975046537357499
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.2380943122476206
# standard deviation: 0.0016455615736149902
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.28348838174817154
# standard deviation: 0.0014913158446648643
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.37276064735734604
# standard deviation: 0.005884898222361933
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5476988864714374
# standard deviation: 0.010265561165041601
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.881028077614699
# standard deviation: 0.017969681926534635
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.62204516916781
# standard deviation: 0.08794954270135641
#
# continuous state space under constant 0.9 order policy:
# mean:  -4.037536707622008
# standard deviation: 0.3713494751315088
#
# continuous state space under constant 1.0 order policy:
# mean:  -71.44397142711726
# standard deviation: 39.14271638987939
#
# continuous state space under constant 1.1 order policy:
# mean:  -991.948387893816
# standard deviation: 92.63155899713566
#
# continuous state space under constant 1.2 order policy:
# mean:  -2011.9291684831983
# standard deviation: 61.98346382164822
#
# continuous state space under constant 1.3 order policy:
# mean:  -3011.5129152333343
# standard deviation: 56.61307538892972
#
# continuous state space under constant 1.4 order policy:
# mean:  -4028.544195570722
# standard deviation: 92.77560169678813
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.2506610755187941
# standard deviation: 0.0019430039657215156
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.22981554507536006
# standard deviation: 0.0016281708105659203
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22458263915755938
# standard deviation: 0.0018970607418020472
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.23944057989616505
# standard deviation: 0.0016246634667955978
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.2823983416434682
# standard deviation: 0.002476370915937266
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.3746261984812331
# standard deviation: 0.0034738459388646238
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5508184409185379
# standard deviation: 0.011360253039215064
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.8801980071635713
# standard deviation: 0.028676472625295324
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.6466334833620606
# standard deviation: 0.11955807513612159
#
# continuous state space under constant 0.9 order policy:
# mean:  -3.9058475259314442
# standard deviation: 0.43521653192708626
#
# continuous state space under constant 1.0 order policy:
# mean:  -71.90120732530995
# standard deviation: 26.66273155509264
#
# continuous state space under constant 1.1 order policy:
# mean:  -999.6671032368389
# standard deviation: 106.75854013879147
#
# continuous state space under constant 1.2 order policy:
# mean:  -2003.4326248005643
# standard deviation: 52.776504176390695
#
# continuous state space under constant 1.3 order policy:
# mean:  -2987.8174914609153
# standard deviation: 64.2246552187546
#
# continuous state space under constant 1.4 order policy:
# mean:  -3989.30555088955
# standard deviation: 46.92593641610899
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.24978116708095038
# standard deviation: 0.00158678845966908
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.2309241411834194
# standard deviation: 0.0018171819116107532
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22460735587933214
# standard deviation: 0.0019668409779902882
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.23899529106629597
# standard deviation: 0.001616619968044399
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.28293320025485746
# standard deviation: 0.0023302648662350913
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.37224408558078137
# standard deviation: 0.0042648074585309595
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5469115537556739
# standard deviation: 0.011355517294833358
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.8949521008444521
# standard deviation: 0.03837766809233414
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.6123728227799354
# standard deviation: 0.07403024201246754
#
# continuous state space under constant 0.9 order policy:
# mean:  -4.257457857529279
# standard deviation: 0.407617701300032
#
# continuous state space under constant 1.0 order policy:
# mean:  -80.00014585723271
# standard deviation: 24.383200862713856
#
# continuous state space under constant 1.1 order policy:
# mean:  -1004.5157358669779
# standard deviation: 91.58467712744209
#
# continuous state space under constant 1.2 order policy:
# mean:  -1979.5861400544502
# standard deviation: 58.19850515038474
#
# continuous state space under constant 1.3 order policy:
# mean:  -3021.54428834669
# standard deviation: 58.30055150922179
#
# continuous state space under constant 1.4 order policy:
# mean:  -3992.8777117788254
# standard deviation: 52.25764413034411
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.24967273652378105
# standard deviation: 0.0017894808645179583
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.23089551695047833
# standard deviation: 0.0014621741361176379
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.22472150313878586
# standard deviation: 0.0024229332685632692
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.23939796084227116
# standard deviation: 0.0014020069488144854
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.28320280239325524
# standard deviation: 0.0024369278334285343
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.3718899209006389
# standard deviation: 0.0037731679962951185
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5539952184587109
# standard deviation: 0.015041816336444469
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.9141658470713885
# standard deviation: 0.02842175962228502
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.661275128594593
# standard deviation: 0.09928947258440533
#
# continuous state space under constant 0.9 order policy:
# mean:  -3.995908668709286
# standard deviation: 0.31249450450423494
#
# continuous state space under constant 1.0 order policy:
# mean:  -84.13138224539848
# standard deviation: 29.767937867380216
#
# continuous state space under constant 1.05 order policy:
# mean:  -148.582130554991
# standard deviation: 52.67886357909295

# %%
numiter = 20000
# print ('discrete state space with Bernoulli demand under random policy:')
# evaluate(random_model, env, numiter)
# print()
# print ('continuous state space with Exp(1) demand under random policy:')
# evaluate(random_model, cont_env, numiter)
# print()

# for i in range(1,6):
#     def constant_model(env):
#         def policy(state):
#             return i
#         return policy
#     print ('discrete state space under constant %s order policy:' %i)
#     evaluate(constant_model, env, numiter)
#     print()

p = 0.25
res_arr = []

for L in [1,4,10,20,30,50,70,100]:
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1}
    cont_env = gym.make('inventory_cont_config_validation_model-v0', 
                    config=ContCONFIG)
    sub_res = []
    for i in range(0,15):
        def constant_model(env):
            def policy(state):
                return np.array([i/10])
#                 return np.array([0])
    #             return i/100
            return policy
        print ('continuous state space under constant %s order policy:' %(i/10))
        avg, std = evaluate(constant_model, cont_env, numiter)
        sub_res.append(avg)
        print()
    res_arr.append(min(sub_res))
# Out:
# continuous state space under constant 0.0 order policy:
# mean:  -0.2491052881229497
# standard deviation: 0.0030109157530770446
#
# continuous state space under constant 1.2 order policy:
# mean:  -1961.803309204408
# standard deviation: 71.50943747290397
#
# continuous state space under constant 1.3 order policy:
# mean:  -3032.1628899208526
# standard deviation: 83.27145177735787
#
# continuous state space under constant 1.4 order policy:
# mean:  -4009.7820438044014
# standard deviation: 97.90952810216707
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.2500904767906821
# standard deviation: 0.001571237484386998
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.22980143878767662
# standard deviation: 0.0011440174383659059
#
# continuous state space under constant 0.2 order policy:
# mean:  -0.2243753419574052
# standard deviation: 0.0012487432178315827
#
# continuous state space under constant 0.3 order policy:
# mean:  -0.23919297090241115
# standard deviation: 0.0012625664536842288
#
# continuous state space under constant 0.4 order policy:
# mean:  -0.2819469024823264
# standard deviation: 0.002540420585848127
#
# continuous state space under constant 0.5 order policy:
# mean:  -0.3726681873884915
# standard deviation: 0.004390903157392292
#
# continuous state space under constant 0.6 order policy:
# mean:  -0.5460288876331585
# standard deviation: 0.015975514569279127
#
# continuous state space under constant 0.7 order policy:
# mean:  -0.9007188382407089
# standard deviation: 0.030736662559924688
#
# continuous state space under constant 0.8 order policy:
# mean:  -1.6604469062021565
# standard deviation: 0.05757070408642932
#
# continuous state space under constant 0.9 order policy:
# mean:  -4.036391762489127
# standard deviation: 0.49455481714479366
#
# continuous state space under constant 1.0 order policy:
# mean:  -71.85925408506934
# standard deviation: 26.32607766647864
#
# continuous state space under constant 1.1 order policy:
# mean:  -986.1880098164096
# standard deviation: 104.68276276052664
#
# continuous state space under constant 1.2 order policy:
# mean:  -2013.2430621837634
# standard deviation: 58.71338457603724
#
# continuous state space under constant 1.3 order policy:
# mean:  -2987.3328655205196
# standard deviation: 50.72287611016344
#
# continuous state space under constant 1.4 order policy:
# mean:  -3903.3087931266937
# standard deviation: 75.83807202329616
#
# continuous state space under constant 0.0 order policy:
# mean:  -0.25057525836046735
# standard deviation: 0.001842264202172894
#
# continuous state space under constant 0.1 order policy:
# mean:  -0.22989744713607826
# standard deviation: 0.0011167520787867323
#
# continuous state space under constant 0.2 order policy:
