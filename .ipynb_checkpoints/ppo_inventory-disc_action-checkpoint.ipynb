# %%
import gym
import numpy as np
import torch as th
import inventory_model
import pandas as pd
from evaluate import *
from ppo_evaluate import ppo_evaluate
import matplotlib.pyplot as plt


from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
#wrapper for cont env with PPO, plot result for several steps
def ppo_eval_interval(p, L, t_t, n_iter, n_step, gae, learning_rate=0.0003):
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1, 'action'=2000}
    PolicyCONFIG = dict(activation_fn=th.nn.Tanh,
                     net_arch=[dict(pi=[64,64], vf=[64, 64])])
    cont_env = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=4, env_kwargs=ContCONFIG)
    print("Running PPO w/: p=", p, ", L=",L)
    cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, gae_lambda=gae, n_epochs = 16,
                     learning_rate = learning_rate,use_sde = False, n_steps = n_step, policy_kwargs = PolicyCONFIG)
    env_eval = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=1, env_kwargs=ContCONFIG)
    timesteps = 0
    numiter = n_iter#test
    res_mean_arr = []
    res_std_arr = []

    while(timesteps <= t_t):

        cont_model.learn(total_timesteps=2*4*n_step-1)#each iteration has 8192 timesteps with n_env=4
        timesteps = timesteps + 2*4*n_step

        res_mean, res_std = ppo_evaluate(cont_model, env_eval, numiter)
        res_mean_arr.append(-res_mean)
        res_std_arr.append(res_std)
        
        if -res_mean == min(res_mean_arr):
            cont_model.save("ppo_min_disc_model_"+str(p)+"_"+str(L))
        
#         print(res_mean_arr)
    
    plt.plot(res_mean_arr)
    plt.xlabel("Iteration")
    plt.ylabel("Average cost")
    plt.title("L="+str(L)+", p="+str(p))
    plt.yscale('log')
    plt.show()
    
    min_model = PPO.load("ppo_min_disc_model_"+str(p)+"_"+str(L))
    mean_min, std_min = ppo_evaluate(min_model, env_eval, 50000)
    print("p="+str(p)+"， L="+str(L)+": mean "+str(-mean_min)+", std_dev: "+str(std_min))
    
    return res_mean_arr, res_std_arr, mean_min, std_min

# %%
# listp = [0.25,1,4,9,39,99]
listp = [4,9,39,99]
# listL = [1,4,70,100]
# listp = [99]
listL = [1]
# t_t = 100000
n_iter = 500
gae_lambda = 0.95
# n_step = 8192
learning_rate = 0.0003
ppo_res = pd.DataFrame(columns = ['p','L','res_mean', 'res_std'])

for p in listp:
    for L in listL:
        n_step = 32*L 
        t_t = 1200*4*n_step
        res_mean, res_std, mean_min, std_min = ppo_eval_interval(p,L,t_t, n_iter, n_step, gae_lambda, learning_rate)
        ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':-mean_min, 'res_std': std_min}, ignore_index=True)
# Out:
# Running PPO w/: p= 4 , L= 1
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 6884 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 128  |
# -----------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1759           |
# |    iterations           | 2              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 256            |
# | train/                  |                |
# |    approx_kl            | -0.00066490844 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | -0.0004        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.4e+04        |
# |    n_updates            | 16             |
# |    policy_gradient_loss | -0.0183        |
# |    value_loss           | 6.63e+04       |
# --------------------------------------------
# mean:  -254.72233866479397
# standard deviation: 18.317555982933182
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5101          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00014972687 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -2.37e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+05      |
# |    n_updates            | 32            |
# |    policy_gradient_loss | -0.00574      |
# |    value_loss           | 3.86e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1285          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00011495501 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -0.00527      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.22e+04      |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.0176       |
# |    value_loss           | 4.31e+04      |
# -------------------------------------------
# mean:  -249.3964675699696
# standard deviation: 14.760412346754322
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8313        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.001044102 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.99       |
# |    explained_variance   | -4.11e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6e+05     |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00794    |
# |    value_loss           | 3.23e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1889         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0007257052 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -0.00293     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.57e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 5.38e+04     |
# ------------------------------------------
# mean:  -227.46335274987223
# standard deviation: 27.23562618466012
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7356          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0011457689 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -4.77e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.23e+05      |
# |    n_updates            | 96            |
# |    policy_gradient_loss | -0.0073       |
# |    value_loss           | 4.5e+05       |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1742         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0009491332 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -0.00119     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.55e+04     |
# |    n_updates            | 112          |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 5.56e+04     |
# ------------------------------------------
# mean:  -251.08415794638395
# standard deviation: 19.67976598439776
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7241          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00022311509 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -4.77e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.15e+05      |
# |    n_updates            | 128           |
# |    policy_gradient_loss | -0.00587      |
# |    value_loss           | 4.55e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1910          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0033893697 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -0.00392      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+04      |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -0.0188       |
# |    value_loss           | 4.65e+04      |
# -------------------------------------------
# mean:  -236.9593812676206
# standard deviation: 20.17389507538065
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7032         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0005296171 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | 3.18e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.5e+05      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0085      |
# |    value_loss           | 2.98e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1882         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.002479326 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | 0.00259      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+04     |
# |    n_updates            | 176          |
# |    policy_gradient_loss | -0.0179      |
# |    value_loss           | 4.97e+04     |
# ------------------------------------------
# mean:  -257.4126964490734
# standard deviation: 12.364342874606738
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6009          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00016250834 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -2.62e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.7e+05       |
# |    n_updates            | 192           |
# |    policy_gradient_loss | -0.00712      |
# |    value_loss           | 3.51e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1729          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0014417656 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.00439       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.3e+04       |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -0.0171       |
# |    value_loss           | 6.99e+04      |
# -------------------------------------------
# mean:  -233.83254050392657
# standard deviation: 13.694279539608962
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 6434           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00057724863 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | -8.34e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.03e+05       |
# |    n_updates            | 224            |
# |    policy_gradient_loss | -0.00774       |
# |    value_loss           | 4.21e+05       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1689         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0016578175 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | 0.00133      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0182      |
# |    value_loss           | 5.31e+04     |
# ------------------------------------------
# mean:  -245.26840326656102
# standard deviation: 10.483300965094534
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6881         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0011199377 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -1.19e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+05     |
# |    n_updates            | 256          |
# |    policy_gradient_loss | -0.00887     |
# |    value_loss           | 3.47e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1739         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0031643882 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | 0.00224      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46e+04     |
# |    n_updates            | 272          |
# |    policy_gradient_loss | -0.0201      |
# |    value_loss           | 2.89e+04     |
# ------------------------------------------
# mean:  -246.80242479983568
# standard deviation: 16.376858160294276
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5291          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0005563237 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 4.42e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.08e+05      |
# |    n_updates            | 288           |
# |    policy_gradient_loss | -0.00849      |
# |    value_loss           | 2.43e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1622          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0015526339 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.0026        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.93e+04      |
# |    n_updates            | 304           |
# |    policy_gradient_loss | -0.0206       |
# |    value_loss           | 4.34e+04      |
# -------------------------------------------
# mean:  -243.53204133479443
# standard deviation: 4.355678277417712
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 4905           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00060912594 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.98          |
# |    explained_variance   | -2.38e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.4e+05        |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -0.00847       |
# |    value_loss           | 2.88e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1463          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0013447516 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000589      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.49e+04      |
# |    n_updates            | 336           |
# |    policy_gradient_loss | -0.0194       |
# |    value_loss           | 4.65e+04      |
# -------------------------------------------
# mean:  -225.87626468156577
# standard deviation: 12.918728902452065
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6452          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0017605387 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -5.96e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.4e+05       |
# |    n_updates            | 352           |
# |    policy_gradient_loss | -0.00872      |
# |    value_loss           | 2.67e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1693          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0011927076 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000543      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+04      |
# |    n_updates            | 368           |
# |    policy_gradient_loss | -0.0217       |
# |    value_loss           | 2.71e+04      |
# -------------------------------------------
# mean:  -235.94755640021563
# standard deviation: 15.696996235376488
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7759          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0014453046 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 1.55e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.12e+05      |
# |    n_updates            | 384           |
# |    policy_gradient_loss | -0.0105       |
# |    value_loss           | 2.54e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1843         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.002632372 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | -0.000868    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.23e+04     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0174      |
# |    value_loss           | 6.46e+04     |
# ------------------------------------------
# mean:  -239.50068681019994
# standard deviation: 23.23030439739366
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7171         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0005245097 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+05     |
# |    n_updates            | 416          |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 3.58e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1877         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0011364482 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.00268      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.9e+04      |
# |    n_updates            | 432          |
# |    policy_gradient_loss | -0.015       |
# |    value_loss           | 6e+04        |
# ------------------------------------------
# mean:  -250.186213596496
# standard deviation: 9.822487214127047
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7350         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0009424798 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 1.13e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.61e+05     |
# |    n_updates            | 448          |
# |    policy_gradient_loss | -0.00863     |
# |    value_loss           | 3.22e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1828         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0019685216 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.000339     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.4e+04      |
# |    n_updates            | 464          |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 6.57e+04     |
# ------------------------------------------
# mean:  -249.95662962199285
# standard deviation: 13.3828455293475
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7421          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00047750399 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.00654      |
# |    value_loss           | 4.27e+05      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1754           |
# |    iterations           | 2              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 256            |
# | train/                  |                |
# |    approx_kl            | -1.1559576e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.98          |
# |    explained_variance   | 0.00167        |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.66e+04       |
# |    n_updates            | 496            |
# |    policy_gradient_loss | -0.0249        |
# |    value_loss           | 3.31e+04       |
# --------------------------------------------
# mean:  -252.65984355609416
# standard deviation: 20.317644654549525
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7263         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | -0.000656534 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+05     |
# |    n_updates            | 512          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 2.57e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1874         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0036602803 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.000549     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.51e+04     |
# |    n_updates            | 528          |
# |    policy_gradient_loss | -0.016       |
# |    value_loss           | 5.03e+04     |
# ------------------------------------------
# mean:  -224.35520548248297
# standard deviation: 19.214184073417734
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7964         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0014601611 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+05     |
# |    n_updates            | 544          |
# |    policy_gradient_loss | -0.00917     |
# |    value_loss           | 2.72e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1786          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0005835369 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000745      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.38e+04      |
# |    n_updates            | 560           |
# |    policy_gradient_loss | -0.0183       |
# |    value_loss           | 5.36e+04      |
# -------------------------------------------
# mean:  -247.57833469414118
# standard deviation: 15.835483606026578
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7046           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -6.5837055e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.97          |
# |    explained_variance   | 1.19e-07       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.94e+05       |
# |    n_updates            | 576            |
# |    policy_gradient_loss | -0.00841       |
# |    value_loss           | 3.99e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1916          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0015380345 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00059       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.98e+04      |
# |    n_updates            | 592           |
# |    policy_gradient_loss | -0.0129       |
# |    value_loss           | 7.92e+04      |
# -------------------------------------------
# mean:  -235.27527087897062
# standard deviation: 16.01882998449067
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7463          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0010119118 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.08e+05      |
# |    n_updates            | 608           |
# |    policy_gradient_loss | -0.00792      |
# |    value_loss           | 4.02e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1866          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0034718812 |
# |    clip_fraction        | 0.00244       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000307      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.8e+04       |
# |    n_updates            | 624           |
# |    policy_gradient_loss | -0.0244       |
# |    value_loss           | 4.03e+04      |
# -------------------------------------------
# mean:  -253.81924708694814
# standard deviation: 20.73225093868702
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7417         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | -0.001813747 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+05     |
# |    n_updates            | 640          |
# |    policy_gradient_loss | -0.00933     |
# |    value_loss           | 3.63e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1866          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0015937574 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000932      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.1e+04       |
# |    n_updates            | 656           |
# |    policy_gradient_loss | -0.0183       |
# |    value_loss           | 4.14e+04      |
# -------------------------------------------
# mean:  -230.45134127548786
# standard deviation: 24.6986938337837
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7394           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00050155073 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.97          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.82e+05       |
# |    n_updates            | 672            |
# |    policy_gradient_loss | -0.0105        |
# |    value_loss           | 3.67e+05       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1782         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0006716661 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.000212     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+04     |
# |    n_updates            | 688          |
# |    policy_gradient_loss | -0.0217      |
# |    value_loss           | 3.56e+04     |
# ------------------------------------------
# mean:  -230.54290490823982
# standard deviation: 16.30184687480338
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7178        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.004430823 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.97       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+05    |
# |    n_updates            | 704         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 2.12e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1859         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0003105998 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.000571     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+04     |
# |    n_updates            | 720          |
# |    policy_gradient_loss | -0.021       |
# |    value_loss           | 3.58e+04     |
# ------------------------------------------
# mean:  -243.6594618195176
# standard deviation: 18.362510217981747
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7284          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00021227822 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.34e+05      |
# |    n_updates            | 736           |
# |    policy_gradient_loss | -0.0099       |
# |    value_loss           | 2.34e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1780          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0002925843 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000815      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.2e+04       |
# |    n_updates            | 752           |
# |    policy_gradient_loss | -0.0182       |
# |    value_loss           | 4.33e+04      |
# -------------------------------------------
# mean:  -230.3410736507833
# standard deviation: 26.132263509857157
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8011          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00052298233 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e+05      |
# |    n_updates            | 768           |
# |    policy_gradient_loss | -0.00963      |
# |    value_loss           | 2.59e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1890         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0013458543 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | 5.62e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.33e+04     |
# |    n_updates            | 784          |
# |    policy_gradient_loss | -0.0177      |
# |    value_loss           | 6.82e+04     |
# ------------------------------------------
# mean:  -228.20213896034437
# standard deviation: 12.641053250996956
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5538         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0022524223 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+05      |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00729     |
# |    value_loss           | 3.78e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1703          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0016798228 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -0.000153     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.61e+04      |
# |    n_updates            | 816           |
# |    policy_gradient_loss | -0.0228       |
# |    value_loss           | 3.35e+04      |
# -------------------------------------------
# mean:  -242.74274619750977
# standard deviation: 21.803703924550213
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7104          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0019303635 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.38e+05      |
# |    n_updates            | 832           |
# |    policy_gradient_loss | -0.01         |
# |    value_loss           | 2.76e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1824          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00049704686 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 0.000221      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.17e+04      |
# |    n_updates            | 848           |
# |    policy_gradient_loss | -0.021        |
# |    value_loss           | 4.74e+04      |
# -------------------------------------------
# mean:  -230.55388619821073
# standard deviation: 22.705951777245243
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7928          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0015026852 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.25e+05      |
# |    n_updates            | 864           |
# |    policy_gradient_loss | -0.0103       |
# |    value_loss           | 2.69e+05      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1768           |
# |    iterations           | 2              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 256            |
# | train/                  |                |
# |    approx_kl            | -0.00035590678 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.97          |
# |    explained_variance   | 0.000429       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.93e+04       |
# |    n_updates            | 880            |
# |    policy_gradient_loss | -0.0171        |
# |    value_loss           | 6.18e+04       |
# --------------------------------------------
# mean:  -250.72642887405155
# standard deviation: 6.468213389041994
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7164          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0010917634 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.82e+05      |
# |    n_updates            | 896           |
# |    policy_gradient_loss | -0.0108       |
# |    value_loss           | 3.36e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1827          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0044702105 |
# |    clip_fraction        | 0.00293       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 0.000388      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.51e+04      |
# |    n_updates            | 912           |
# |    policy_gradient_loss | -0.0264       |
# |    value_loss           | 2.95e+04      |
# -------------------------------------------
# mean:  -234.8764758603357
# standard deviation: 21.263142790727464
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7332         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0010673776 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+05      |
# |    n_updates            | 928          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 2.33e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1754         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# ...
# |    value_loss           | 4.87e+04     |
# ------------------------------------------
# mean:  -227.7918191548228
# standard deviation: 23.126083937443955
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7877         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0018638521 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+05     |
# |    n_updates            | 864          |
# |    policy_gradient_loss | -0.00712     |
# |    value_loss           | 3.5e+05      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1765          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0009866208 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -0.000552     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.48e+04      |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.0234       |
# |    value_loss           | 2.95e+04      |
# -------------------------------------------
# mean:  -234.88764341941774
# standard deviation: 25.63220490116512
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7859         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0015570931 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | -3.58e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+05     |
# |    n_updates            | 896          |
# |    policy_gradient_loss | -0.00904     |
# |    value_loss           | 2.27e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1836        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.004812766 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.97       |
# |    explained_variance   | 0.000627    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+04     |
# |    n_updates            | 912         |
# |    policy_gradient_loss | -0.0182     |
# |    value_loss           | 5.6e+04     |
# -----------------------------------------
# mean:  -221.13190841271876
# standard deviation: 18.50352473775192
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 8349           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00040854886 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.96          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.72e+05       |
# |    n_updates            | 928            |
# |    policy_gradient_loss | -0.00808       |
# |    value_loss           | 3.68e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1673          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0024086833 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 3.05e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.9e+04       |
# |    n_updates            | 944           |
# |    policy_gradient_loss | -0.0243       |
# |    value_loss           | 4.09e+04      |
# -------------------------------------------
# mean:  -230.4567682996988
# standard deviation: 17.54602206297805
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6182          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00042663515 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.26e+05      |
# |    n_updates            | 960           |
# |    policy_gradient_loss | -0.00961      |
# |    value_loss           | 2.63e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1789         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0004869774 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | 0.000148     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.78e+04     |
# |    n_updates            | 976          |
# |    policy_gradient_loss | -0.0197      |
# |    value_loss           | 5.71e+04     |
# ------------------------------------------
# mean:  -233.45479677968623
# standard deviation: 23.633137705405595
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8022          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0013915151 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.95         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.47e+05      |
# |    n_updates            | 992           |
# |    policy_gradient_loss | -0.0102       |
# |    value_loss           | 2.93e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1886         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.002252806 |
# |    clip_fraction        | 0.00195      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | 0.000319     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.21e+04     |
# |    n_updates            | 1008         |
# |    policy_gradient_loss | -0.0233      |
# |    value_loss           | 4.62e+04     |
# ------------------------------------------
# mean:  -234.26497941603662
# standard deviation: 7.2320584761277384
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5915          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0016848817 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.95         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.75e+05      |
# |    n_updates            | 1024          |
# |    policy_gradient_loss | -0.00778      |
# |    value_loss           | 3.55e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1713         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.000586316 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.96        |
# |    explained_variance   | 0.000113     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68e+04     |
# |    n_updates            | 1040         |
# |    policy_gradient_loss | -0.0188      |
# |    value_loss           | 5.34e+04     |
# ------------------------------------------
# mean:  -230.44645581260025
# standard deviation: 13.821149899814815
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5670          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0010516383 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.95         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.88e+05      |
# |    n_updates            | 1056          |
# |    policy_gradient_loss | -0.0107       |
# |    value_loss           | 3.5e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1689          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0029381402 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.96         |
# |    explained_variance   | 5.6e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+04      |
# |    n_updates            | 1072          |
# |    policy_gradient_loss | -0.0191       |
# |    value_loss           | 3.99e+04      |
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9a015f4182eb> in <module>
#      15         n_step = 32*L
#      16         t_t = 1200*4*n_step
# ---> 17         res_mean, res_std, mean_min, std_min = ppo_eval_interval(p,L,t_t, n_iter, n_step, gae_lambda, learning_rate)
#      18         ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':-mean_min, 'res_std': std_min}, ignore_index=True)
#
# <ipython-input-3-ae9ae2ceccf1> in ppo_eval_interval(p, L, t_t, n_iter, n_step, gae, learning_rate)
#      19         timesteps = timesteps + 2*4*n_step
#      20
# ---> 21         res_mean, res_std = ppo_evaluate(cont_model, env_eval, numiter)
#      22         res_mean_arr.append(-res_mean)
#      23         res_std_arr.append(res_std)
#
# ~/Desktop/2021 Spring/6590 Approx DP & RL/Project/Project_code/gym-inventory/ppo_evaluate.py in ppo_evaluate(model, env, numiter)
#      12
#      13         for j in range(numiter):
# ---> 14             action, _states = model.predict(obs)
#      15             obs, rewards, dones, info = env.step(action)
#      16             reward[j] = rewards
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     495             (used in recurrent policies)
#     496         """
# --> 497         return self.policy.predict(observation, state, mask, deterministic)
#     498
#     499     def set_random_seed(self, seed: Optional[int] = None) -> None:
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/policies.py in predict(self, observation, state, mask, deterministic)
#     274         observation = th.as_tensor(observation).to(self.device)
#     275         with th.no_grad():
# --> 276             actions = self._predict(observation, deterministic=deterministic)
#     277         # Convert to numpy
#     278         actions = actions.cpu().numpy()
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/policies.py in _predict(self, observation, deterministic)
#     593         :return: Taken action according to the policy
#     594         """
# --> 595         latent_pi, _, latent_sde = self._get_latent(observation)
#     596         distribution = self._get_action_dist_from_latent(latent_pi, latent_sde)
#     597         return distribution.get_actions(deterministic=deterministic)
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/policies.py in _get_latent(self, obs)
#     550         """
#     551         # Preprocess the observation if needed
# --> 552         features = self.extract_features(obs)
#     553         latent_pi, latent_vf = self.mlp_extractor(features)
#     554
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/policies.py in extract_features(self, obs)
#     117         assert self.features_extractor is not None, "No features extractor was set"
#     118         preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 119         return self.features_extractor(preprocessed_obs)
#     120
#     121     def _get_constructor_parameters(self) -> Dict[str, Any]:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/torch_layers.py in forward(self, observations)
#      45
#      46     def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 47         return self.flatten(observations)
#      48
#      49
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/flatten.py in forward(self, input)
#      38
#      39     def forward(self, input: Tensor) -> Tensor:
# ---> 40         return input.flatten(self.start_dim, self.end_dim)
#      41
#      42     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
ppo_res

# %%
plt.plot(res_mean)

# %% [markdown]
# ## Below is obsolete.
