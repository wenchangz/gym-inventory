# %%
import gym
import numpy as np
import inventory_model
import pandas as pd
from evaluate import *
from ppo_evaluate import ppo_evaluate
import matplotlib as plt


from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
#wrapper for cont env, plot result for several steps
def ppo_eval_interval(p, L, t_t, n_iter, learning_rate=0.0003):
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1}
    cont_env = make_vec_env('inventory_cont_config_fix_model-v0', n_envs=4, env_kwargs=ContCONFIG)
    print("Running PPO w/: p=", p, ", L=",L)
    cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, learning_rate = learning_rate,use_sde = False)
    env_eval = make_vec_env('inventory_cont_config_fix_model-v0', n_envs=1, env_kwargs=ContCONFIG)
    timesteps = 0
    numiter = n_iter#test
    res_mean_arr = []
    res_std_arr = []

    while(timesteps <= t_t):

        cont_model.learn(total_timesteps=8000)#each iteration has 8192 timesteps with n_env=4
        timesteps = timesteps + 8192

        res_mean, res_std = ppo_evaluate(cont_model, env_eval, numiter)
        res_mean_arr.append(-res_mean)
        res_std_arr.append(res_std)
        print(res_mean_arr)
    
#     plt.pyplot.plot(res_mean_arr)

    return res_mean_arr, res_std_arr

# %%
# listp = [0.25,1,4,9,39,99]
# listL = [30,50,70,100]
listp = [99]
listL = [100]
t_t = 500000
n_iter = 1000
learning_rate = 0.00001
ppo_res = pd.DataFrame(columns = ['p','L','res_mean', 'res_std'])

for p in listp:
    for L in listL:
        res_mean, res_std = ppo_eval_interval(p,L,t_t, n_iter, learning_rate)
        ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':min(res_mean), 'res_std': res_std[np.argmin(res_mean)]}, ignore_index=True)
# Out:
# Running PPO w/: p= 99 , L= 100
# Using cpu device
# --------------------------------------
# | time/                   |          |
# |    fps                  | 4761     |
# |    iterations           | 1        |
# |    time_elapsed         | 1        |
# |    total_timesteps      | 8192     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | 5.49     |
# |    explained_variance   | 5.96e-08 |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.94e+06 |
# |    n_updates            | 340      |
# |    policy_gradient_loss | 1.39e-08 |
# |    std                  | 1        |
# |    value_loss           | 3.9e+06  |
# --------------------------------------
# mean:  -64.30167265549343
# standard deviation: 4.079466802845889
# [64.30167265549343]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5770         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 6.506154e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000149    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.2e+05      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -8.74e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 1.6e+06      |
# ------------------------------------------
# mean:  -61.08662280524898
# standard deviation: 2.966720161518568
# [64.30167265549343, 61.08662280524898]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5678          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.6234553e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.00112      |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.43e+05      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -6.09e-05     |
# |    std                  | 0.999         |
# |    value_loss           | 1.67e+06      |
# -------------------------------------------
# mean:  -64.63585838901375
# standard deviation: 3.3753414288308425
# [64.30167265549343, 61.08662280524898, 64.63585838901375]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5587        |
# |    iterations           | 1           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 4.34533e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | -0.00118    |
# |    learning_rate        | 1e-05       |
# |    loss                 | 9.18e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.000153   |
# |    std                  | 0.999       |
# |    value_loss           | 1.63e+06    |
# -----------------------------------------
# mean:  -62.92593609936811
# standard deviation: 3.076334586509202
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5599           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -3.4251789e-06 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -0.000938      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.66e+05       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -4.37e-05      |
# |    std                  | 0.999          |
# |    value_loss           | 1.59e+06       |
# --------------------------------------------
# mean:  -64.23531041609644
# standard deviation: 2.6823731114745986
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5644         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 2.592062e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000887    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.04e+05     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -4.37e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 1.5e+06      |
# ------------------------------------------
# mean:  -62.45749354253694
# standard deviation: 3.497381041774287
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5601         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 9.485208e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000718    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 8.21e+05     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -4.66e-05    |
# |    std                  | 0.998        |
# |    value_loss           | 1.59e+06     |
# ------------------------------------------
# mean:  -64.27997582838373
# standard deviation: 3.2598110431774003
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5480          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.1823067e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000597     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.72e+05      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -4.5e-05      |
# |    std                  | 0.997         |
# |    value_loss           | 1.49e+06      |
# -------------------------------------------
# mean:  -62.374894954746686
# standard deviation: 2.7445972657547797
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5638         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 8.829126e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -0.000489    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 8.03e+05     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -6.04e-05    |
# |    std                  | 0.997        |
# |    value_loss           | 1.61e+06     |
# ------------------------------------------
# mean:  -62.91666733586474
# standard deviation: 1.5034712258504563
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5753          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 2.9642455e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -0.000437     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.75e+05      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -4.27e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 1.61e+06      |
# -------------------------------------------
# mean:  -64.36023559183698
# standard deviation: 3.394803535477342
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5780        |
# |    iterations           | 1           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 9.05394e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.000354   |
# |    learning_rate        | 1e-05       |
# |    loss                 | 8.72e+05    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -8.18e-05   |
# |    std                  | 0.996       |
# |    value_loss           | 1.77e+06    |
# -----------------------------------------
# mean:  -61.94530840892794
# standard deviation: 2.049895163769505
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4788          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | -3.657624e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.000433     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.17e+05      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -3.96e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 1.61e+06      |
# -------------------------------------------
# mean:  -64.41570291965635
# standard deviation: 1.6709635047875497
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5355          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.6746206e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.000388     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.18e+05      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -8.53e-05     |
# |    std                  | 0.995         |
# |    value_loss           | 1.5e+06       |
# -------------------------------------------
# mean:  -61.683154036357735
# standard deviation: 3.896114101129017
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5859           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -2.0136365e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.41          |
# |    explained_variance   | -0.000357      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 9.15e+05       |
# |    n_updates            | 130            |
# |    policy_gradient_loss | -5.24e-05      |
# |    std                  | 0.995          |
# |    value_loss           | 1.6e+06        |
# --------------------------------------------
# mean:  -62.86055061074878
# standard deviation: 3.065091721057403
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5528        |
# |    iterations           | 1           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 2.37715e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -0.000201   |
# |    learning_rate        | 1e-05       |
# |    loss                 | 7.47e+05    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -4.32e-05   |
# |    std                  | 0.995       |
# |    value_loss           | 1.57e+06    |
# -----------------------------------------
# mean:  -61.75669963779565
# standard deviation: 2.832859689752652
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5276           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.2892386e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.41          |
# |    explained_variance   | -0.000109      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.65e+05       |
# |    n_updates            | 150            |
# |    policy_gradient_loss | -5.2e-05       |
# |    std                  | 0.996          |
# |    value_loss           | 1.56e+06       |
# --------------------------------------------
# mean:  -63.49569644842984
# standard deviation: 2.8044195101114515
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5708          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.3707388e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.000108     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.48e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -5.43e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 1.62e+06      |
# -------------------------------------------
# mean:  -64.17935583224428
# standard deviation: 1.0171582822875203
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5752           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.4420271e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -0.000135      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.77e+05       |
# |    n_updates            | 170            |
# |    policy_gradient_loss | -4.85e-05      |
# |    std                  | 0.996          |
# |    value_loss           | 1.53e+06       |
# --------------------------------------------
# mean:  -60.81265003678857
# standard deviation: 3.7706962101475137
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5544           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.7981729e-06 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -0.000117      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.42e+05       |
# |    n_updates            | 180            |
# |    policy_gradient_loss | -3.51e-05      |
# |    std                  | 0.996          |
# |    value_loss           | 1.55e+06       |
# --------------------------------------------
# mean:  -61.381768120984205
# standard deviation: 3.8515584193815076
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4701          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 5.9615842e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.000119     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.72e+05      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -8.78e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 1.57e+06      |
# -------------------------------------------
# mean:  -61.88726658624368
# standard deviation: 1.9665075213677852
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 4744          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00012010309 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -0.000116     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.58e+05      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -0.000157     |
# |    std                  | 0.995         |
# |    value_loss           | 1.55e+06      |
# -------------------------------------------
# mean:  -65.0228528696146
# standard deviation: 4.750257769803382
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 4699           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.5218102e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.41          |
# |    explained_variance   | -0.000105      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.5e+05        |
# |    n_updates            | 210            |
# |    policy_gradient_loss | -4.6e-05       |
# |    std                  | 0.996          |
# |    value_loss           | 1.56e+06       |
# --------------------------------------------
# mean:  -63.19180369811647
# standard deviation: 2.6634035540981165
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4881         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 6.381604e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | -7.03e-05    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.65e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -8.69e-05    |
# |    std                  | 0.996        |
# |    value_loss           | 1.66e+06     |
# ------------------------------------------
# mean:  -63.475587700589315
# standard deviation: 5.780808344941341
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5750          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | -6.642797e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -4.99e-05     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.15e+05      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000106     |
# |    std                  | 0.996         |
# |    value_loss           | 1.56e+06      |
# -------------------------------------------
# mean:  -63.40909042437833
# standard deviation: 2.2119942700221786
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5858           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -3.2360374e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.41          |
# |    explained_variance   | -7.06e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 6.84e+05       |
# |    n_updates            | 240            |
# |    policy_gradient_loss | -3.95e-05      |
# |    std                  | 0.996          |
# |    value_loss           | 1.52e+06       |
# --------------------------------------------
# mean:  -63.099322414572065
# standard deviation: 2.4000966643137955
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5874         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0001180874 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -4.53e-05    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.05e+05     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -5.17e-05    |
# |    std                  | 0.996        |
# |    value_loss           | 1.56e+06     |
# ------------------------------------------
# mean:  -63.14765638161937
# standard deviation: 3.0537536144801876
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5778          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 4.6541463e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | -8.15e-05     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.66e+05      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -5.23e-05     |
# |    std                  | 0.996         |
# |    value_loss           | 1.54e+06      |
# -------------------------------------------
# mean:  -61.92186410603902
# standard deviation: 2.1088887658171083
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5479           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -2.7937327e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -4.72e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.41e+05       |
# |    n_updates            | 270            |
# |    policy_gradient_loss | -4.39e-05      |
# |    std                  | 0.997          |
# |    value_loss           | 1.62e+06       |
# --------------------------------------------
# mean:  -61.67269869642378
# standard deviation: 2.1174501624955435
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5570           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -0.00012543521 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -3.62e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.31e+05       |
# |    n_updates            | 280            |
# |    policy_gradient_loss | -6.74e-05      |
# |    std                  | 0.997          |
# |    value_loss           | 1.52e+06       |
# --------------------------------------------
# mean:  -63.4018566421023
# standard deviation: 4.951182136844441
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5599          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 5.2237818e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -3.85e-05     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.27e+05      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000155     |
# |    std                  | 0.998         |
# |    value_loss           | 1.5e+06       |
# -------------------------------------------
# mean:  -60.34147899012885
# standard deviation: 2.7025197316417002
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5791           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.6495964e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -3.56e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.06e+05       |
# |    n_updates            | 300            |
# |    policy_gradient_loss | -8.41e-05      |
# |    std                  | 0.998          |
# |    value_loss           | 1.5e+06        |
# --------------------------------------------
# mean:  -60.00244790613442
# standard deviation: 2.502127381811084
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5748         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 4.189185e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -4.63e-05    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 9.15e+05     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -5.15e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 1.58e+06     |
# ------------------------------------------
# mean:  -63.8741313941012
# standard deviation: 2.872751792736803
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5669           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -5.1963223e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -4.67e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.04e+05       |
# |    n_updates            | 320            |
# |    policy_gradient_loss | -7.88e-05      |
# |    std                  | 0.999          |
# |    value_loss           | 1.56e+06       |
# --------------------------------------------
# mean:  -61.040372123734166
# standard deviation: 2.305105158361068
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5476           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -3.1793243e-06 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -3.83e-05      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.41e+05       |
# |    n_updates            | 330            |
# |    policy_gradient_loss | -2.84e-05      |
# |    std                  | 0.999          |
# |    value_loss           | 1.52e+06       |
# --------------------------------------------
# mean:  -61.1444740723061
# standard deviation: 4.32908165948089
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5460          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 5.9145117e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -1.96e-05     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 9.27e+05      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -6.76e-05     |
# |    std                  | 0.999         |
# |    value_loss           | 1.63e+06      |
# -------------------------------------------
# mean:  -62.68380624122725
# standard deviation: 3.4271238883056947
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5177         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 9.553522e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -3.6e-05     |
# |    learning_rate        | 1e-05        |
# |    loss                 | 8.11e+05     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -7.71e-05    |
# |    std                  | 0.999        |
# |    value_loss           | 1.55e+06     |
# ------------------------------------------
# mean:  -65.34027727724077
# standard deviation: 2.6371133962949798
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5481           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -1.1630662e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -1.5e-05       |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.73e+05       |
# |    n_updates            | 360            |
# |    policy_gradient_loss | -4.48e-05      |
# |    std                  | 1              |
# |    value_loss           | 1.62e+06       |
# --------------------------------------------
# mean:  -63.8780979586237
# standard deviation: 3.608037892461534
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5774          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | -2.721884e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -2.06e-05     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.27e+05      |
# |    n_updates            | 370           |
# |    policy_gradient_loss | -3.26e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.51e+06      |
# -------------------------------------------
# mean:  -64.59715820298968
# standard deviation: 2.120425743313229
# ...
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 1.0675954e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -6.79e-06     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 8.54e+05      |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -3.88e-05     |
# |    std                  | 0.997         |
# |    value_loss           | 1.57e+06      |
# -------------------------------------------
# mean:  -62.05021672759043
# standard deviation: 1.535771658284214
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5703         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 2.075285e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -5.48e-06    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 7.67e+05     |
# |    n_updates            | 550          |
# |    policy_gradient_loss | -6.44e-05    |
# |    std                  | 0.998        |
# |    value_loss           | 1.63e+06     |
# ------------------------------------------
# mean:  -62.683437955864804
# standard deviation: 1.0844964907090473
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5778           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -0.00010352993 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -3.7e-06       |
# |    learning_rate        | 1e-05          |
# |    loss                 | 6.57e+05       |
# |    n_updates            | 560            |
# |    policy_gradient_loss | -0.000119      |
# |    std                  | 0.998          |
# |    value_loss           | 1.42e+06       |
# --------------------------------------------
# mean:  -60.70124761181067
# standard deviation: 1.8642788098516527
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5939         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 7.582677e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | -5.01e-06    |
# |    learning_rate        | 1e-05        |
# |    loss                 | 6.86e+05     |
# |    n_updates            | 570          |
# |    policy_gradient_loss | -9.7e-05     |
# |    std                  | 0.997        |
# |    value_loss           | 1.55e+06     |
# ------------------------------------------
# mean:  -61.382582962529
# standard deviation: 3.0390713244589116
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067, 61.382582962529]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5708           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -8.5256033e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -3.46e-06      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 8.18e+05       |
# |    n_updates            | 580            |
# |    policy_gradient_loss | -5.73e-05      |
# |    std                  | 0.997          |
# |    value_loss           | 1.54e+06       |
# --------------------------------------------
# mean:  -61.02462866625616
# standard deviation: 3.947804038089818
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067, 61.382582962529, 61.02462866625616]
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 5736          |
# |    iterations           | 1             |
# |    time_elapsed         | 1             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | -3.898461e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | -2.26e-06     |
# |    learning_rate        | 1e-05         |
# |    loss                 | 7.25e+05      |
# |    n_updates            | 590           |
# |    policy_gradient_loss | -6.16e-05     |
# |    std                  | 0.998         |
# |    value_loss           | 1.46e+06      |
# -------------------------------------------
# mean:  -60.83515499617964
# standard deviation: 2.7026649764149537
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067, 61.382582962529, 61.02462866625616, 60.83515499617964]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5573           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -2.3899433e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -7.27e-06      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 7.95e+05       |
# |    n_updates            | 600            |
# |    policy_gradient_loss | -7.66e-05      |
# |    std                  | 0.998          |
# |    value_loss           | 1.4e+06        |
# --------------------------------------------
# mean:  -61.219595160035816
# standard deviation: 3.1996436024159247
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067, 61.382582962529, 61.02462866625616, 60.83515499617964, 61.219595160035816]
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 5644           |
# |    iterations           | 1              |
# |    time_elapsed         | 1              |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -3.2872224e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.42          |
# |    explained_variance   | -7.15e-06      |
# |    learning_rate        | 1e-05          |
# |    loss                 | 6.44e+05       |
# |    n_updates            | 610            |
# |    policy_gradient_loss | -4.67e-05      |
# |    std                  | 0.998          |
# |    value_loss           | 1.48e+06       |
# --------------------------------------------
# mean:  -59.19682268508758
# standard deviation: 2.3982725400955576
# [64.30167265549343, 61.08662280524898, 64.63585838901375, 62.92593609936811, 64.23531041609644, 62.45749354253694, 64.27997582838373, 62.374894954746686, 62.91666733586474, 64.36023559183698, 61.94530840892794, 64.41570291965635, 61.683154036357735, 62.86055061074878, 61.75669963779565, 63.49569644842984, 64.17935583224428, 60.81265003678857, 61.381768120984205, 61.88726658624368, 65.0228528696146, 63.19180369811647, 63.475587700589315, 63.40909042437833, 63.099322414572065, 63.14765638161937, 61.92186410603902, 61.67269869642378, 63.4018566421023, 60.34147899012885, 60.00244790613442, 63.8741313941012, 61.040372123734166, 61.1444740723061, 62.68380624122725, 65.34027727724077, 63.8780979586237, 64.59715820298968, 62.768591064745536, 60.35208535869464, 62.49731114348505, 63.72016678877003, 60.534962210432, 61.32105087396019, 61.631526636993705, 59.393059968577234, 60.78017856556944, 62.07328332832408, 58.50271300899119, 61.53212039046995, 64.25377724518765, 64.10855335760296, 63.11762158769062, 60.856427324423024, 62.05021672759043, 62.683437955864804, 60.70124761181067, 61.382582962529, 61.02462866625616, 60.83515499617964, 61.219595160035816, 59.19682268508758]

# %%
ppo_res
# Out:
#       p      L   res_mean   res_std
# 0  99.0  100.0  59.462613  1.545864

# %%
plt.pyplot.plot(res_mean)

# %% [markdown]
# ## Below is obsolete.

# %%
#wrapper for continuous environment, obsolete
def ppo_eval(p, L, t_t, n_iter, learning_rate=0.0003):
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1}
    cont_env = make_vec_env('inventory_cont_config_fix_model-v0', n_envs=4, env_kwargs=ContCONFIG)
    print("Running PPO w/: p=", p, ", L=",L)
    cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, learning_rate = learning_rate,use_sde = False)
    cont_model.learn(total_timesteps=t_t)#testing 2000

    cont_model.save("inv_cont_2")
    trained_model = PPO.load("inv_cont_2")
    env_eval = make_vec_env('inventory_cont_config_fix_model-v0', n_envs=1, env_kwargs=ContCONFIG)
    numiter = n_iter#test
    res_mean, res_std = ppo_evaluate(trained_model, env_eval, numiter)
    print(-res_mean,'+/=',1.96*res_std/np.sqrt(5)) 

    return res_mean, res_std

# %%
# listp = [0.25,1,4,9,39,99]
# listL = [1,4,10,20,30,50,70,100]
listp = [39]
listL = [1]
t_t = 200000
n_iter = 100000
learning_rate = 0.005
ppo_res = pd.DataFrame(columns = ['p','L','res_mean', 'res_std'])

for p in listp:
    for L in listL:
        res_mean, res_std = ppo_eval(p,L,t_t, n_iter, learning_rate)
        ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':res_mean, 'res_std': res_std}, ignore_index=True)
# Out:
# Running PPO w/: p= 39 , L= 1
# Using cpu device
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 8028        |
# |    iterations           | 1           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.001326405 |
# |    clip_fraction        | 0.00736     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.39       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.08e+05    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0027     |
# |    std                  | 0.975       |
# |    value_loss           | 9.34e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3105        |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010170783 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.000163    |
# |    learning_rate        | 0.005       |
# |    loss                 | 1.08e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00991    |
# |    std                  | 1.05        |
# |    value_loss           | 9.62e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2573       |
# |    iterations           | 3          |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.60280055 |
# |    clip_fraction        | 0.158      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | -1.55e-06  |
# |    learning_rate        | 0.005      |
# |    loss                 | 8.18e+03   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00118   |
# |    std                  | 1.15       |
# |    value_loss           | 6.92e+04   |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2298      |
# |    iterations           | 4         |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.3622134 |
# |    clip_fraction        | 0.852     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.56     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.005     |
# |    loss                 | 5.43e+09  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | 0.257     |
# |    std                  | 1.15      |
# |    value_loss           | 9.77e+09  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2188         |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 4.868634e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.005        |
# |    loss                 | 4.03e+10     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | 4e-06        |
# |    std                  | 1.15         |
# |    value_loss           | 8.08e+10     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2114         |
# |    iterations           | 6            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 6.626564e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.005        |
# |    loss                 | 1.15e+11     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -6.44e-06    |
# |    std                  | 1.15         |
# |    value_loss           | 2.43e+11     |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2070           |
# |    iterations           | 7              |
# |    time_elapsed         | 27             |
# |    total_timesteps      | 57344          |
# | train/                  |                |
# |    approx_kl            | -1.8142775e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.56          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.005          |
# |    loss                 | 2.44e+11       |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -1.68e-05      |
# |    std                  | 1.15           |
# |    value_loss           | 4.96e+11       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2041          |
# |    iterations           | 8             |
# |    time_elapsed         | 32            |
# |    total_timesteps      | 65536         |
# | train/                  |               |
# |    approx_kl            | 5.6965204e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.005         |
# |    loss                 | 4.05e+11      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -6.62e-06     |
# |    std                  | 1.15          |
# |    value_loss           | 8.36e+11      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2016           |
# |    iterations           | 9              |
# |    time_elapsed         | 36             |
# |    total_timesteps      | 73728          |
# | train/                  |                |
# |    approx_kl            | -4.6222587e-05 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.56          |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.005          |
# |    loss                 | 6.41e+11       |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -2e-05         |
# |    std                  | 1.15           |
# |    value_loss           | 1.27e+12       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1995         |
# |    iterations           | 10           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | -9.49204e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.005        |
# |    loss                 | 8.87e+11     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -1.29e-08    |
# |    std                  | 1.15         |
# |    value_loss           | 1.79e+12     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1978         |
# |    iterations           | 11           |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 3.000324e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.005        |
# |    loss                 | 1.21e+12     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 1.15         |
# |    value_loss           | 2.4e+12      |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1951          |
# |    iterations           | 12            |
# |    time_elapsed         | 50            |
# |    total_timesteps      | 98304         |
# | train/                  |               |
# |    approx_kl            | 1.1588811e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.005         |
# |    loss                 | 1.56e+12      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -1.04e-07     |
# |    std                  | 1.15          |
# |    value_loss           | 3.1e+12       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1935          |
# |    iterations           | 13            |
# |    time_elapsed         | 55            |
# |    total_timesteps      | 106496        |
# | train/                  |               |
# |    approx_kl            | 1.1466109e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.005         |
# |    loss                 | 1.94e+12      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | 1.81e-06      |
# |    std                  | 1.16          |
# |    value_loss           | 3.89e+12      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1920         |
# |    iterations           | 14           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# |    approx_kl            | 3.086697e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.005        |
# |    loss                 | 2.41e+12     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -2.44e-06    |
# |    std                  | 1.16         |
# |    value_loss           | 4.76e+12     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1896          |
# |    iterations           | 15            |
# |    time_elapsed         | 64            |
# |    total_timesteps      | 122880        |
# | train/                  |               |
# |    approx_kl            | 2.4442037e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.56         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.005         |
# |    loss                 | 2.87e+12      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -2.77e-07     |
# |    std                  | 1.16          |
# |    value_loss           | 5.73e+12      |
# -------------------------------------------
# ---------------------------------------------
# | time/                   |                 |
# |    fps                  | 1883            |
# |    iterations           | 16              |
# |    time_elapsed         | 69              |
# |    total_timesteps      | 131072          |
# | train/                  |                 |
# |    approx_kl            | -1.16198935e-05 |
# |    clip_fraction        | 0               |
# |    clip_range           | 0.2             |
# |    entropy_loss         | -1.56           |
# |    explained_variance   | -1.19e-07       |
# |    learning_rate        | 0.005           |
# |    loss                 | 3.42e+12        |
# |    n_updates            | 150             |
# |    policy_gradient_loss | -0.000266       |
# |    std                  | 1.16            |
# |    value_loss           | 6.79e+12        |
# ---------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b1d84fe3ecd5> in <module>
#      10 for p in listp:
#      11     for L in listL:
# ---> 12         res_mean, res_std = ppo_eval(p,L,t_t, n_iter, learning_rate)
#      13         ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':res_mean, 'res_std': res_std}, ignore_index=True)
#
# <ipython-input-7-8e450b44397a> in ppo_eval(p, L, t_t, n_iter, learning_rate)
#       5     print("Running PPO w/: p=", p, ", L=",L)
#       6     cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, learning_rate = learning_rate,use_sde = False)
# ----> 7     cont_model.learn(total_timesteps=t_t)#testing 2000
#       8
#       9     cont_model.save("inv_cont_2")
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     278     ) -> "PPO":
#     279
# --> 280         return super(PPO, self).learn(
#     281             total_timesteps=total_timesteps,
#     282             callback=callback,
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245                 logger.dump(step=self.num_timesteps)
#     246
# --> 247             self.train()
#     248
#     249         callback.on_training_end()
#
# ~/anaconda3/lib/python3.8/site-packages/stable_baselines3/ppo/ppo.py in train(self)
#     234                 # Optimization step
#     235                 self.policy.optimizer.zero_grad()
# --> 236                 loss.backward()
#     237                 # Clip grad norm
#     238                 th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# ~/anaconda3/lib/python3.8/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     143         retain_graph = create_graph
#     144
# --> 145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
ppo_res

# %%
#continuous model try with cont action

# #env = make_vec_env('inventory_cont_model-v0', ContCONFIG = {'h': 1, 'p': 1, 'L': 10, 'lambda': 1}, n_envs=4)
# #how to set parameters???
# cont_env = make_vec_env('inventory_cont_model-v0', n_envs=8)
# cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1)
# cont_model.learn(total_timesteps=200000)
# # fixed issue with vector, now action can be continuous

# #continuous evaluation
# cont_model.save("inv_cont_1")
# trained_model = PPO.load("inv_cont_1")
# env1 = gym.make('inventory_cont_model-v0')
# numiter = 50000
# res_mean, res_std = ppo_evaluate(trained_model, env1, numiter)
# print(-res_mean,'+/=',1.96*res_std/np.sqrt(5))

# %%
#Discrete environment
# #h=1,p=99,L=1,max_inventory=100,max_action=100,binomial(6,0.5)
# env = make_vec_env('inventory_model-v0', n_envs=4)
# model = PPO(MlpPolicy, env, verbose=1, gamma = 1)
# model.learn(total_timesteps=1000000)
# model.save("inv_2")

# trained_model2 = PPO.load("inv_2")
# env2 = gym.make('inventory_model-v0')
# numiter = 200000
# res_mean, res_std = ppo_evaluate(trained_model2, env2, numiter)
# print(-res_mean,'+/=',1.96*res_std/np.sqrt(5))

# %%
#Discrete environment 2
#h=1,p=99,L=1,max_inventory=100,max_action=6,binomial(6,0.5)
# env = make_vec_env('inventory_model-v0', n_envs=4)
# model = PPO(MlpPolicy, env, verbose=1, gamma = 1)
# model.learn(total_timesteps=1000000)
# model.save("inv_3")

# #set action space to be small([0,1,2,3,4,5,6]) seems to get reasonable results...
# trained_model3 = PPO.load("inv_3")
# env3 = gym.make('inventory_model-v0')
# numiter = 200000
# res_mean, res_std = ppo_evaluate(trained_model3, env3, numiter)
# print(-res_mean,'+/=',1.96*res_std/np.sqrt(5))
