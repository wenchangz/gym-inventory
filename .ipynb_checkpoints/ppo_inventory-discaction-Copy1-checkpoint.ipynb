# %%
import gym
import numpy as np
import inventory_model
import pandas as pd
from evaluate import *
from ppo_evaluate import ppo_evaluate
import matplotlib as plt


from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
#wrapper for cont env with PPO, plot result for several steps
def ppo_eval_interval(p, L, t_t, n_iter, n_step, gae, learning_rate=0.0003):
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1}
    cont_env = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=4, env_kwargs=ContCONFIG)
    print("Running PPO w/: p=", p, ", L=",L)
    cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, 
                     learning_rate = learning_rate,use_sde = False, gae_lambda = gae, n_steps = n_step)
    env_eval = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=1, env_kwargs=ContCONFIG)
    timesteps = 0
    numiter = n_iter#test
    res_mean_arr = []
    res_std_arr = []

    while(timesteps <= t_t):

        cont_model.learn(total_timesteps=60000)#each iteration has 8192 timesteps with n_env=4
        timesteps = timesteps + 32767+32767

        res_mean, res_std = ppo_evaluate(cont_model, env_eval, numiter)
        res_mean_arr.append(-res_mean)
        res_std_arr.append(res_std)
        print(res_mean_arr)
    
#     plt.pyplot.plot(res_mean_arr)

    return res_mean_arr, res_std_arr

# %%
listp = [0.25,1,4,9,39,99]
# listL = [30,50,70,100]
# listp = [99]
# listL = [100]
t_t = 2000000
n_iter = 10000 #for eval
n_step = 8192
learning_rate = 0.0003
gae_lambda = 0.99
ppo_res = pd.DataFrame(columns = ['p','L','res_mean', 'res_std'])

for p in listp:
    for L in listL:
        res_mean, res_std = ppo_eval_interval(p,L,t_t, n_iter, n_step, gae_lambda, learning_rate)
        ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':min(res_mean), 'res_std': res_std[np.argmin(res_mean)]}, ignore_index=True)
# Out:
# Running PPO w/: p= 99 , L= 100
# Using cpu device
# ------------------------------
# | time/              |       |
# |    fps             | 5910  |
# |    iterations      | 1     |
# |    time_elapsed    | 5     |
# |    total_timesteps | 32768 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2679        |
# |    iterations           | 2           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.003299642 |
# |    clip_fraction        | 0.00366     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | -4.26e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.47e+06    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00164    |
# |    value_loss           | 2.89e+06    |
# -----------------------------------------
# mean:  -15.776481163822726
# standard deviation: 1.3060728215844857
# [15.776481163822726]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6570        |
# |    iterations           | 1           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003847796 |
# |    clip_fraction        | 0.00981     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.99       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+06    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00131    |
# |    value_loss           | 3.57e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2767         |
# |    iterations           | 2            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0046830866 |
# |    clip_fraction        | 0.00878      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.99        |
# |    explained_variance   | -3.03e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31e+06     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 2.64e+06     |
# ------------------------------------------
# mean:  -18.400210500252307
# standard deviation: 0.9336927482640516
# [15.776481163822726, 18.400210500252307]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6570         |
# |    iterations           | 1            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0019968539 |
# |    clip_fraction        | 0.000122     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+06     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000855    |
# |    value_loss           | 5.53e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2736         |
# |    iterations           | 2            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0060899435 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.91e+06     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 7.12e+06     |
# ------------------------------------------
# mean:  -23.228450148501146
# standard deviation: 10.523887459397393
# [15.776481163822726, 18.400210500252307, 23.228450148501146]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6502         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0063961744 |
# |    clip_fraction        | 0.00447      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+06     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 2.27e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2753        |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004132673 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.83e+06    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 3.92e+06    |
# -----------------------------------------
# mean:  -15.856132579498782
# standard deviation: 0.5774692430347315
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6168         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0064021777 |
# |    clip_fraction        | 0.018        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.69e+06     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 3.59e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2689         |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0036257189 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.52e+06     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00209     |
# |    value_loss           | 3.09e+06     |
# ------------------------------------------
# mean:  -17.4193287448831
# standard deviation: 2.5015700028346033
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6549        |
# |    iterations           | 1           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005289982 |
# |    clip_fraction        | 0.0102      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.42e+06    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00189    |
# |    value_loss           | 3.43e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2738        |
# |    iterations           | 2           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004560062 |
# |    clip_fraction        | 0.00413     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+06    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 2.73e+06    |
# -----------------------------------------
# mean:  -18.032189008691184
# standard deviation: 1.1010178233998793
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6654        |
# |    iterations           | 1           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006459621 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.2e+06     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 2.5e+06     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2712       |
# |    iterations           | 2          |
# |    time_elapsed         | 24         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.00588187 |
# |    clip_fraction        | 0.00367    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.92      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+06   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00188   |
# |    value_loss           | 2.94e+06   |
# ----------------------------------------
# mean:  -16.81015420013587
# standard deviation: 1.5164503923389179
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6490         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0040190113 |
# |    clip_fraction        | 0.00266      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.84e+06     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 6.41e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2681         |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0031338783 |
# |    clip_fraction        | 0.00482      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33e+06     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 4.61e+06     |
# ------------------------------------------
# mean:  -20.493970676537295
# standard deviation: 4.6630080252091775
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6690         |
# |    iterations           | 1            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0063294903 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.93        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+06     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 2.45e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2720         |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0025608623 |
# |    clip_fraction        | 0.00101      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.58e+06     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 3.37e+06     |
# ------------------------------------------
# mean:  -18.90614142310249
# standard deviation: 1.9381898409072447
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6551        |
# |    iterations           | 1           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006052758 |
# |    clip_fraction        | 0.00544     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.92       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23e+06    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00128    |
# |    value_loss           | 4.16e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2705        |
# |    iterations           | 2           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.004122014 |
# |    clip_fraction        | 0.00162     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.62e+06    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00136    |
# |    value_loss           | 3.92e+06    |
# -----------------------------------------
# mean:  -15.09682173549989
# standard deviation: 0.9156385111298109
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6515         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0066912677 |
# |    clip_fraction        | 0.0227       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.46e+06     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 6.19e+06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2697        |
# |    iterations           | 2           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008488084 |
# |    clip_fraction        | 0.0133      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+06    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0028     |
# |    value_loss           | 2.36e+06    |
# -----------------------------------------
# mean:  -15.102501823938402
# standard deviation: 0.5206312242839124
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6578         |
# |    iterations           | 1            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0054391976 |
# |    clip_fraction        | 0.0101       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+06     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 2.8e+06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2681         |
# |    iterations           | 2            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0063705915 |
# |    clip_fraction        | 0.00139      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.92        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.22e+06     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 2.4e+06      |
# ------------------------------------------
# mean:  -18.530907437436973
# standard deviation: 1.897932461233572
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402, 18.530907437436973]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6588        |
# |    iterations           | 1           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007941377 |
# |    clip_fraction        | 0.0059      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.09e+06    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00195    |
# |    value_loss           | 2.36e+06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2561        |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.006378439 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87e+06    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00191    |
# |    value_loss           | 4.42e+06    |
# -----------------------------------------
# mean:  -16.02599813713433
# standard deviation: 1.0910603463073048
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402, 18.530907437436973, 16.02599813713433]
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5814        |
# |    iterations           | 1           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003922552 |
# |    clip_fraction        | 0.00552     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+06     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00155    |
# |    value_loss           | 2.47e+06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2288         |
# |    iterations           | 2            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0045799715 |
# |    clip_fraction        | 0.00355      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.36e+06     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 2.98e+06     |
# ------------------------------------------
# mean:  -16.29018604237184
# standard deviation: 1.7097286027199392
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402, 18.530907437436973, 16.02599813713433, 16.29018604237184]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6130         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0052479324 |
# |    clip_fraction        | 0.00673      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.86e+05     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0023      |
# |    value_loss           | 2.2e+06      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2399        |
# |    iterations           | 2           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005304748 |
# |    clip_fraction        | 0.00627     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.07e+06    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00214    |
# |    value_loss           | 2.57e+06    |
# -----------------------------------------
# mean:  -15.54538163620441
# standard deviation: 0.5184979517724774
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402, 18.530907437436973, 16.02599813713433, 16.29018604237184, 15.54538163620441]
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5698         |
# |    iterations           | 1            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0071099335 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.49e+06     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0028      |
# |    value_loss           | 2.65e+06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2467         |
# |    iterations           | 2            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0074047553 |
# |    clip_fraction        | 0.00271      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.91        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.17e+06     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00227     |
# |    value_loss           | 2.23e+06     |
# ------------------------------------------
# mean:  -18.480259608585637
# standard deviation: 2.5439838863216324
# [15.776481163822726, 18.400210500252307, 23.228450148501146, 15.856132579498782, 17.4193287448831, 18.032189008691184, 16.81015420013587, 20.493970676537295, 18.90614142310249, 15.09682173549989, 15.102501823938402, 18.530907437436973, 16.02599813713433, 16.29018604237184, 15.54538163620441, 18.480259608585637]

# %%
ppo_res
# Out:
#       p      L   res_mean   res_std
# 0  99.0  100.0  15.096822  0.915639

# %%
plt.pyplot.plot(res_mean)
