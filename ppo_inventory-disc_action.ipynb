# %%
import gym
import numpy as np
import torch as th
import inventory_model
import pandas as pd
from evaluate import *
from ppo_evaluate import ppo_evaluate
import matplotlib.pyplot as plt


from stable_baselines3 import PPO
from stable_baselines3.ppo import MlpPolicy
from stable_baselines3.common.env_util import make_vec_env

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
#wrapper for cont env with PPO, plot result for several steps
def ppo_eval_interval(p, L, t_t, n_iter, n_step, gae, learning_rate=0.0003):
    ContCONFIG = {'h': 1, 'p': p, 'L': L, 'lambda': 1, 'action': 400}
    PolicyCONFIG = dict(activation_fn=th.nn.Tanh,
                     net_arch=[dict(pi=[64,64], vf=[64, 64])])
    cont_env = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=4, env_kwargs=ContCONFIG)
    print("Running PPO w/: p=", p, ", L=",L)
    cont_model = PPO(MlpPolicy, cont_env, verbose=1, gamma = 1, gae_lambda=gae, n_epochs = 16,
                     learning_rate = learning_rate,use_sde = False, n_steps = n_step, policy_kwargs = PolicyCONFIG)
    env_eval = make_vec_env('inventory_cont_disc_action_config_fix_model-v0', n_envs=1, env_kwargs=ContCONFIG)
    timesteps = 0
    numiter = n_iter#test
    res_mean_arr = []
    res_std_arr = []

    while(timesteps <= t_t):

        cont_model.learn(total_timesteps=2*4*n_step-1)#each iteration has 8192 timesteps with n_env=4
        timesteps = timesteps + 2*4*n_step

        res_mean, res_std = ppo_evaluate(cont_model, env_eval, numiter)
        res_mean_arr.append(-res_mean)
        res_std_arr.append(res_std)
        
        if -res_mean == min(res_mean_arr):
            cont_model.save("ppo_min_disc_model_"+str(p)+"_"+str(L))
        
#         print(res_mean_arr)
    
    plt.plot(res_mean_arr)
    plt.xlabel("Iteration")
    plt.ylabel("Average cost")
    plt.title("L="+str(L)+", p="+str(p))
    plt.yscale('log')
    plt.show()
    
    min_model = PPO.load("ppo_min_disc_model_"+str(p)+"_"+str(L))
    mean_min, std_min = ppo_evaluate(min_model, env_eval, 50000)
    print("p="+str(p)+"， L="+str(L)+": mean "+str(-mean_min)+", std_dev: "+str(std_min))
    
    return res_mean_arr, res_std_arr, mean_min, std_min

# %%
# listp = [0.25,1,4,9,39,99]
listp = [4,9,39,99]
# listL = [1,4,70,100]
# listp = [99]
listL = [1]
# t_t = 100000
n_iter = 500
gae_lambda = 0.95
# n_step = 8192
learning_rate = 0.0003
ppo_res = pd.DataFrame(columns = ['p','L','res_mean', 'res_std'])

for p in listp:
    for L in listL:
        n_step = 32*L 
        t_t = 1200*4*n_step
        res_mean, res_std, mean_min, std_min = ppo_eval_interval(p,L,t_t, n_iter, n_step, gae_lambda, learning_rate)
        ppo_res = ppo_res.append({'p': p, 'L':L, 'res_mean':-mean_min, 'res_std': std_min}, ignore_index=True)
# Out:
# Running PPO w/: p= 4 , L= 1
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 6493 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 128  |
# -----------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1802          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00019500032 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.00131       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.31e+04      |
# |    n_updates            | 16            |
# |    policy_gradient_loss | -0.0194       |
# |    value_loss           | 6.35e+04      |
# -------------------------------------------
# mean:  -235.08825649798808
# standard deviation: 22.80193621964001
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 8523           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00092055276 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | 0.000188       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.19e+05       |
# |    n_updates            | 32             |
# |    policy_gradient_loss | -0.00306       |
# |    value_loss           | 4.45e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1798          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00091987103 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.00172       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+04      |
# |    n_updates            | 48            |
# |    policy_gradient_loss | -0.0146       |
# |    value_loss           | 5.19e+04      |
# -------------------------------------------
# mean:  -251.9492651098639
# standard deviation: 24.650570386435128
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6238        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | -0.00234548 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.99       |
# |    explained_variance   | 0.000127    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63e+05    |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 3.2e+05     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1496          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0011083409 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.0036        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.27e+04      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.0191       |
# |    value_loss           | 2.55e+04      |
# -------------------------------------------
# mean:  -250.79411978833377
# standard deviation: 15.941016572022674
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7690           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00040556118 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | -3.77e-05      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 9.7e+04        |
# |    n_updates            | 96             |
# |    policy_gradient_loss | -0.0108        |
# |    value_loss           | 2.02e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1679          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0033071935 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.000647      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.73e+04      |
# |    n_updates            | 112           |
# |    policy_gradient_loss | -0.0148       |
# |    value_loss           | 6.18e+04      |
# -------------------------------------------
# mean:  -250.25944237772222
# standard deviation: 16.397505077233042
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7789           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00030124187 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | -5.48e-06      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.9e+05        |
# |    n_updates            | 128            |
# |    policy_gradient_loss | -0.00692       |
# |    value_loss           | 4.12e+05       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1813          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0038893037 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 6.58e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.1e+04       |
# |    n_updates            | 144           |
# |    policy_gradient_loss | -0.018        |
# |    value_loss           | 4.42e+04      |
# -------------------------------------------
# mean:  -250.61479798194168
# standard deviation: 19.07864693335126
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6920          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00068388134 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -1.28e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.71e+05      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00849      |
# |    value_loss           | 3.5e+05       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1892          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0022371933 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | -0.00241      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.2e+03       |
# |    n_updates            | 176           |
# |    policy_gradient_loss | -0.0243       |
# |    value_loss           | 1.83e+04      |
# -------------------------------------------
# mean:  -244.10943498470783
# standard deviation: 20.883430691327643
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7209         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0005312823 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -1.49e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.12e+05     |
# |    n_updates            | 192          |
# |    policy_gradient_loss | -0.00959     |
# |    value_loss           | 2.34e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1792          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0013268664 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 0.00279       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.31e+04      |
# |    n_updates            | 208           |
# |    policy_gradient_loss | -0.0152       |
# |    value_loss           | 6.74e+04      |
# -------------------------------------------
# mean:  -255.58260770266946
# standard deviation: 9.335987323495745
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7386           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00043827295 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.99          |
# |    explained_variance   | 7.39e-06       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.74e+05       |
# |    n_updates            | 224            |
# |    policy_gradient_loss | -0.00767       |
# |    value_loss           | 3.22e+05       |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1904         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.005983714 |
# |    clip_fraction        | 0.000488     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.99        |
# |    explained_variance   | -0.00158     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.37e+04     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.0234      |
# |    value_loss           | 2.52e+04     |
# ------------------------------------------
# mean:  -243.95200666240754
# standard deviation: 28.049890533058626
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7381          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00050482526 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -1.3e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.33e+05      |
# |    n_updates            | 256           |
# |    policy_gradient_loss | -0.00685      |
# |    value_loss           | 2.51e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1864          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00032508373 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.99         |
# |    explained_variance   | 9.1e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.1e+04       |
# |    n_updates            | 272           |
# |    policy_gradient_loss | -0.0193       |
# |    value_loss           | 4.03e+04      |
# -------------------------------------------
# mean:  -239.14694170662762
# standard deviation: 14.0299689969464
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 5533         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 8.463487e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 4.89e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.23e+05     |
# |    n_updates            | 288          |
# |    policy_gradient_loss | -0.00811     |
# |    value_loss           | 2.31e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1631        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.001394067 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.99       |
# |    explained_variance   | 0.00233     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.92e+03    |
# |    n_updates            | 304         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 1.88e+04    |
# -----------------------------------------
# mean:  -232.02333888076842
# standard deviation: 16.060840014013486
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 8057          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0015605018 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 1.07e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.19e+05      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00822      |
# |    value_loss           | 2.37e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1756        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.000353083 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.98       |
# |    explained_variance   | 0.000421    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.29e+04    |
# |    n_updates            | 336         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 5.17e+04    |
# -----------------------------------------
# mean:  -246.67077899101076
# standard deviation: 23.9783492886509
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7554          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0008751154 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 9.54e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.69e+05      |
# |    n_updates            | 352           |
# |    policy_gradient_loss | -0.00802      |
# |    value_loss           | 3.46e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1678          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0010444932 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00183       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.64e+04      |
# |    n_updates            | 368           |
# |    policy_gradient_loss | -0.0163       |
# |    value_loss           | 4.83e+04      |
# -------------------------------------------
# mean:  -232.7563933886409
# standard deviation: 13.224702127502027
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6373         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 9.736046e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | -4.77e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.9e+05      |
# |    n_updates            | 384          |
# |    policy_gradient_loss | -0.00817     |
# |    value_loss           | 3.75e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1644         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0004514195 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.98        |
# |    explained_variance   | 0.00183      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.9e+04      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0139      |
# |    value_loss           | 6.81e+04     |
# ------------------------------------------
# mean:  -248.28391918094158
# standard deviation: 24.331370363694806
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6561          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0017121732 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.55e+05      |
# |    n_updates            | 416           |
# |    policy_gradient_loss | -0.0073       |
# |    value_loss           | 3.62e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1699          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00020385161 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00131       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.16e+04      |
# |    n_updates            | 432           |
# |    policy_gradient_loss | -0.0187       |
# |    value_loss           | 4.58e+04      |
# -------------------------------------------
# mean:  -249.829845090279
# standard deviation: 12.632453039109937
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6395          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0022396706 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -9.54e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.6e+05       |
# |    n_updates            | 448           |
# |    policy_gradient_loss | -0.00844      |
# |    value_loss           | 3.15e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1698          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0045489334 |
# |    clip_fraction        | 0.00928       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000697      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+04      |
# |    n_updates            | 464           |
# |    policy_gradient_loss | -0.02         |
# |    value_loss           | 4.34e+04      |
# -------------------------------------------
# mean:  -241.05467323821782
# standard deviation: 16.718454690713564
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6128          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0023913644 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -1.55e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.16e+05      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -0.0092       |
# |    value_loss           | 2.43e+05      |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1734       |
# |    iterations           | 2          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.00094679 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.98      |
# |    explained_variance   | 0.0011     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.9e+04    |
# |    n_updates            | 496        |
# |    policy_gradient_loss | -0.0151    |
# |    value_loss           | 5.52e+04   |
# ----------------------------------------
# mean:  -248.85652135489732
# standard deviation: 16.358530036298948
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6105        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.002566453 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.98       |
# |    explained_variance   | -3.58e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.91e+05    |
# |    n_updates            | 512         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 3.4e+05     |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1727          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0032295175 |
# |    clip_fraction        | 0.000977      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00224       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.63e+04      |
# |    n_updates            | 528           |
# |    policy_gradient_loss | -0.0177       |
# |    value_loss           | 4.98e+04      |
# -------------------------------------------
# mean:  -241.5909350435674
# standard deviation: 6.102009588317591
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6589          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00080237165 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -5.96e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.66e+05      |
# |    n_updates            | 544           |
# |    policy_gradient_loss | -0.00973      |
# |    value_loss           | 3.12e+05      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | -0.00395602 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.98       |
# |    explained_variance   | 0.000964    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.08e+04    |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 4.18e+04    |
# -----------------------------------------
# mean:  -248.3705699304819
# standard deviation: 23.675201159730893
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6470          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0009440556 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+05      |
# |    n_updates            | 576           |
# |    policy_gradient_loss | -0.00677      |
# |    value_loss           | 3.18e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1672          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0009983741 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000212      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.99e+04      |
# |    n_updates            | 592           |
# |    policy_gradient_loss | -0.0176       |
# |    value_loss           | 6.09e+04      |
# -------------------------------------------
# mean:  -229.14646939718722
# standard deviation: 20.98948687152779
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6638          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0003541261 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.77e+05      |
# |    n_updates            | 608           |
# |    policy_gradient_loss | -0.00877      |
# |    value_loss           | 3.74e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1696          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0010845959 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | -8.83e-05     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.34e+04      |
# |    n_updates            | 624           |
# |    policy_gradient_loss | -0.0184       |
# |    value_loss           | 4.45e+04      |
# -------------------------------------------
# mean:  -238.3920748195648
# standard deviation: 26.86229610503173
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7348          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | 0.00041969866 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.29e+05      |
# |    n_updates            | 640           |
# |    policy_gradient_loss | -0.00943      |
# |    value_loss           | 2.84e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1909          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 8.5990876e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 7.7e-05       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.44e+04      |
# |    n_updates            | 656           |
# |    policy_gradient_loss | -0.017        |
# |    value_loss           | 6.56e+04      |
# -------------------------------------------
# mean:  -247.668059593156
# standard deviation: 23.749066735862304
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7232          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0013478771 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.98e+05      |
# |    n_updates            | 672           |
# |    policy_gradient_loss | -0.00688      |
# |    value_loss           | 3.94e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1919          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0028403737 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00149       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.52e+04      |
# |    n_updates            | 688           |
# |    policy_gradient_loss | -0.0177       |
# |    value_loss           | 4.93e+04      |
# -------------------------------------------
# mean:  -237.49250622695982
# standard deviation: 19.366080094555432
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7395         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0013319664 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.59e+05     |
# |    n_updates            | 704          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 3.33e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1898          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00016058609 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000536      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.77e+04      |
# |    n_updates            | 720           |
# |    policy_gradient_loss | -0.0194       |
# |    value_loss           | 3.19e+04      |
# -------------------------------------------
# mean:  -242.14235309526322
# standard deviation: 9.753017507134944
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6669          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0009390302 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -2.38e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.28e+05      |
# |    n_updates            | 736           |
# |    policy_gradient_loss | -0.00867      |
# |    value_loss           | 2.51e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1691          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0005376525 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.00025       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.68e+04      |
# |    n_updates            | 752           |
# |    policy_gradient_loss | -0.016        |
# |    value_loss           | 6.8e+04       |
# -------------------------------------------
# mean:  -232.2297892489672
# standard deviation: 26.290994906690482
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7510         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0005089715 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.19e+05     |
# |    n_updates            | 768          |
# |    policy_gradient_loss | -0.00622     |
# |    value_loss           | 4.01e+05     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1838          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0028102882 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 8.68e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.67e+04      |
# |    n_updates            | 784           |
# |    policy_gradient_loss | -0.0154       |
# |    value_loss           | 5.89e+04      |
# -------------------------------------------
# mean:  -223.64386496458647
# standard deviation: 16.441081525094244
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6641          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0018765181 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.8e+05       |
# |    n_updates            | 800           |
# |    policy_gradient_loss | -0.0067       |
# |    value_loss           | 3.69e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1691          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -4.028529e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000566      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.29e+04      |
# |    n_updates            | 816           |
# |    policy_gradient_loss | -0.0171       |
# |    value_loss           | 4.68e+04      |
# -------------------------------------------
# mean:  -229.1675594637647
# standard deviation: 18.90332994702139
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7703          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0009958483 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 2.98e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+05      |
# |    n_updates            | 832           |
# |    policy_gradient_loss | -0.00825      |
# |    value_loss           | 3.27e+05      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 1954           |
# |    iterations           | 2              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 256            |
# | train/                  |                |
# |    approx_kl            | -0.00050519034 |
# |    clip_fraction        | 0.00195        |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -5.98          |
# |    explained_variance   | 0.000526       |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.53e+04       |
# |    n_updates            | 848            |
# |    policy_gradient_loss | -0.0191        |
# |    value_loss           | 4.86e+04       |
# --------------------------------------------
# mean:  -247.93660285879372
# standard deviation: 16.47833319319099
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 6733          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0004892461 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.61e+05      |
# |    n_updates            | 864           |
# |    policy_gradient_loss | -0.00813      |
# |    value_loss           | 3.23e+05      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1743          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0015783608 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.98         |
# |    explained_variance   | 0.000123      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.68e+04      |
# |    n_updates            | 880           |
# |    policy_gradient_loss | -0.0195       |
# |    value_loss           | 3.63e+04      |
# -------------------------------------------
# mean:  -227.64314825157527
# standard deviation: 9.289815074066412
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7372          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0011119358 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -5.97         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.66e+05      |
# |    n_updates            | 896           |
# |    policy_gradient_loss | -0.00793      |
# |    value_loss           | 3.27e+05      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1862         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0005524568 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | 0.000211     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38e+04     |
# |    n_updates            | 912          |
# |    policy_gradient_loss | -0.019       |
# |    value_loss           | 4.47e+04     |
# ------------------------------------------
# mean:  -218.64545493773593
# standard deviation: 16.259928286138386
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 8057         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | -0.001338195 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.97        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.55e+05     |
# |    n_updates            | 928          |
# |    policy_gradient_loss | -0.00915     |
# |    value_loss           | 3.14e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1791        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# ...
# |    fps                  | 1770          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | -0.0034693033 |
# |    clip_fraction        | 0.148         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.89         |
# |    explained_variance   | -2.62e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 238           |
# |    n_updates            | 8528          |
# |    policy_gradient_loss | -0.0361       |
# |    value_loss           | 583           |
# -------------------------------------------
# mean:  -2.137936128428392
# standard deviation: 0.09892855840370222
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7855        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.016500644 |
# |    clip_fraction        | 0.0366      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -8.34e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 344         |
# |    n_updates            | 8544        |
# |    policy_gradient_loss | -0.0232     |
# |    value_loss           | 683         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1711        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.015446413 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | -2.03e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 249         |
# |    n_updates            | 8560        |
# |    policy_gradient_loss | -0.0287     |
# |    value_loss           | 533         |
# -----------------------------------------
# mean:  -2.157100970238168
# standard deviation: 0.05317837123716014
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7052           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00030846894 |
# |    clip_fraction        | 0.103          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.68          |
# |    explained_variance   | -9.54e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 222            |
# |    n_updates            | 8576           |
# |    policy_gradient_loss | -0.0271        |
# |    value_loss           | 489            |
# --------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1741         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | -0.009667847 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.97        |
# |    explained_variance   | -7.15e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 637          |
# |    n_updates            | 8592         |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 1.18e+03     |
# ------------------------------------------
# mean:  -2.225925701518263
# standard deviation: 0.10546314564272846
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 7931           |
# |    iterations           | 1              |
# |    time_elapsed         | 0              |
# |    total_timesteps      | 128            |
# | train/                  |                |
# |    approx_kl            | -0.00022980385 |
# |    clip_fraction        | 0.0366         |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.57          |
# |    explained_variance   | -4.77e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 265            |
# |    n_updates            | 8608           |
# |    policy_gradient_loss | -0.0214        |
# |    value_loss           | 537            |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1993        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.004026113 |
# |    clip_fraction        | 0.0342      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | -1.43e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 348         |
# |    n_updates            | 8624        |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 760         |
# -----------------------------------------
# mean:  -2.2718255879098086
# standard deviation: 0.19846977453584622
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7421        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | -0.00871145 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 4.17e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 226         |
# |    n_updates            | 8640        |
# |    policy_gradient_loss | -0.0217     |
# |    value_loss           | 477         |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 1906          |
# |    iterations           | 2             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 256           |
# | train/                  |               |
# |    approx_kl            | 0.00073807314 |
# |    clip_fraction        | 0.063         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.61         |
# |    explained_variance   | -2.03e-06     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 241           |
# |    n_updates            | 8656          |
# |    policy_gradient_loss | -0.0227       |
# |    value_loss           | 470           |
# -------------------------------------------
# mean:  -2.1374829573650382
# standard deviation: 0.07039239171132977
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7586          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0013762396 |
# |    clip_fraction        | 0.108         |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.77         |
# |    explained_variance   | 8.34e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 372           |
# |    n_updates            | 8672          |
# |    policy_gradient_loss | -0.035        |
# |    value_loss           | 765           |
# -------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1772       |
# |    iterations           | 2          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 256        |
# | train/                  |            |
# |    approx_kl            | 0.02436984 |
# |    clip_fraction        | 0.0757     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.73      |
# |    explained_variance   | -2.98e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 310        |
# |    n_updates            | 8688       |
# |    policy_gradient_loss | -0.0274    |
# |    value_loss           | 624        |
# ----------------------------------------
# mean:  -2.255357710182224
# standard deviation: 0.0924128894055764
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 7313       |
# |    iterations           | 1          |
# |    time_elapsed         | 0          |
# |    total_timesteps      | 128        |
# | train/                  |            |
# |    approx_kl            | 0.02833806 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.16      |
# |    explained_variance   | 5.36e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 305        |
# |    n_updates            | 8704       |
# |    policy_gradient_loss | -0.0336    |
# |    value_loss           | 560        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1899        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.024561033 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | -2.98e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 306         |
# |    n_updates            | 8720        |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 647         |
# -----------------------------------------
# mean:  -2.147626136159926
# standard deviation: 0.09026740717076505
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 7431         |
# |    iterations           | 1            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 128          |
# | train/                  |              |
# |    approx_kl            | 0.0076659415 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 329          |
# |    n_updates            | 8736         |
# |    policy_gradient_loss | -0.0249      |
# |    value_loss           | 664          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1781        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 0.006374277 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 267         |
# |    n_updates            | 8752        |
# |    policy_gradient_loss | -0.0218     |
# |    value_loss           | 590         |
# -----------------------------------------
# mean:  -2.2634869694473223
# standard deviation: 0.12435947066297619
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 7246          |
# |    iterations           | 1             |
# |    time_elapsed         | 0             |
# |    total_timesteps      | 128           |
# | train/                  |               |
# |    approx_kl            | -0.0029837377 |
# |    clip_fraction        | 0.0176        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.41         |
# |    explained_variance   | -3.58e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 430           |
# |    n_updates            | 8768          |
# |    policy_gradient_loss | -0.0132       |
# |    value_loss           | 968           |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1857         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0014753602 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.43        |
# |    explained_variance   | -1.67e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 341          |
# |    n_updates            | 8784         |
# |    policy_gradient_loss | -0.0147      |
# |    value_loss           | 593          |
# ------------------------------------------
# mean:  -2.263924664851464
# standard deviation: 0.12920585916019517
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7794        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.008111028 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 1.01e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 435         |
# |    n_updates            | 8800        |
# |    policy_gradient_loss | -0.0285     |
# |    value_loss           | 824         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1823         |
# |    iterations           | 2            |
# |    time_elapsed         | 0            |
# |    total_timesteps      | 256          |
# | train/                  |              |
# |    approx_kl            | 0.0020399299 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | -5.96e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 311          |
# |    n_updates            | 8816         |
# |    policy_gradient_loss | -0.0249      |
# |    value_loss           | 635          |
# ------------------------------------------
# mean:  -2.2042576486089267
# standard deviation: 0.08967412342090796
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 7160        |
# |    iterations           | 1           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 128         |
# | train/                  |             |
# |    approx_kl            | 0.003839681 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 438         |
# |    n_updates            | 8832        |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 913         |
# -----------------------------------------

# %%
ppo_res

# %%
plt.plot(res_mean)

# %% [markdown]
# ## Below is obsolete.
